# %% [markdown]
# # Product Classifier Training
#
# Uses the included synthetic demo images for a smoke test. For evaluated work, place a real five-class image dataset in `data/product_images/train` and train MobileNetV2.

# %%
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ROOT

# %%
# !python {ROOT / 'scripts/train_product_classifier.py'} --demo

# %%
# Real transfer learning (requires requirements-ml.txt and a real image folder):
# !python {ROOT / 'scripts/train_product_classifier.py'} --data-dir {ROOT / 'data/product_images/train'} --epochs 8
