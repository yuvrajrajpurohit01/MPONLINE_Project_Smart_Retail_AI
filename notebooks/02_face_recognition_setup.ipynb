# %% [markdown]
# # Consent-Based Face Recognition Setup
#
# The project deliberately ships with an empty face database. Register only volunteers who explicitly consent, and provide opt-out and deletion processes.

# %%
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ROOT

# %%
import pickle
with open(ROOT / 'app/models/face_db.pkl', 'rb') as f:
    db = pickle.load(f)
len(db['customers']), db.keys()

# %%
# Folder names: CUSTOMER_ID__Customer_Name
# !python {ROOT / 'scripts/register_faces.py'} {ROOT / 'data/sample_faces'} --consent-confirmed
