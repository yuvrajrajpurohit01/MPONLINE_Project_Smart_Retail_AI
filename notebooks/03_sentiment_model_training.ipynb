# %% [markdown]
# # Sentiment Model Training
#
# Trains the TF-IDF + logistic-regression baseline required by the document and prints a held-out classification report.

# %%
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
ROOT

# %%
import pandas as pd
reviews = pd.read_csv(ROOT / 'data/reviews.csv')
reviews.head(), reviews['sentiment'].value_counts()

# %%
# !python {ROOT / 'scripts/train_sentiment.py'}
